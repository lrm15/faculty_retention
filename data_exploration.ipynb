# %%
import pandas as pd

# %%
df = pd.read_csv("Master_v2.csv")

# %%
df[df.College == "Williams"]
# Out:
#        Unnamed: 0   College  Year      Last    First Middle  \
# 0               1  Williams  2018  a. lindo   haydee     m.
# 1               2  Williams  2019  a. lindo   haydee     m.
# 2               3  Williams  2020  a. lindo   haydee     m.
# 13             14  Williams  2007  aalberts   daniel     p.
# 14             15  Williams  2008  aalberts   daniel     p.
# ...           ...       ...   ...       ...      ...    ...
# 22734       22735  Williams  2011   zottoli   steven     j.
# 22735       22736  Williams  2012   zottoli   steven     j.
# 22736       22737  Williams  2013   zottoli   steven     j.
# 22737       22738  Williams  2019       zug  charles     u.
# 22738       22739  Williams  2020       zug  charles     u.
#
#                    Department         Position  \
# 0                    ['math']  assistant prof.
# 1                    ['math']  assistant prof.
# 2                    ['math']  assistant prof.
# 13                ['physics']  associate prof.
# ...

# %%
df[df.ga_gender == "female"].count()
# Out:
# Unnamed: 0       9664
# College          9664
# Year             9664
# Last             9660
# First            9660
# Middle           5404
# Department       9664
# Position         9479
# Title            9477
# Tenured          9664
# Visiting         9664
# Leave            3623
# Education        9155
# Entire.Line       966
# ga_first_name    9664
# ga_gender        9664
# ga_accuracy      9664
# ga_samples       9664
# dtype: int64

# %%
df[df.ga_gender == "male"].count()
# Out:
# Unnamed: 0       12845
# College          12845
# Year             12845
# Last             12845
# First            12845
# Middle            8048
# Department       12843
# Position         12597
# Title            12594
# Tenured          12845
# Visiting         12845
# Leave             4863
# Education        12108
# Entire.Line       1114
# ga_first_name    12845
# ga_gender        12845
# ga_accuracy      12845
# ga_samples       12845
# dtype: int64

# %%
# Out:
# Unnamed: 0
# College
# Year
# Last
# First
# Middle
# Department
# Position
# Title
# Tenured
# Visiting
# Leave
# Education
# Entire.Line
# ga_first_name
# ga_gender
# ga_accuracy
# ga_samples
