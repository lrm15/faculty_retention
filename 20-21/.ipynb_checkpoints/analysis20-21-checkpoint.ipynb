# %%
import pandas as pd
from pathlib import Path

# %%
df = pd.read_csv('faculty20-21.csv')
df.drop("Unnamed: 0", inplace=True, axis=1)

# %%
df
# Out:
#                     name                                              title  \
# 0     Daniel P. Aalberts     Kennedy P. Richardson '71 Professor of Physics
# 1    Tomas Adalsteinsson  Assistant Professor of Physical Education and ...
# 2         Colin C. Adams            Thomas T. Read Professor of Mathematics
# 3            Zaid Adhami  Assistant Professor of Religion and Faculty Af...
# 4     Jeannie R Albrecht                      Professor of Computer Science
# ..                   ...                                                ...
# 430         Safa R. Zaki       Dean of the Faculty, Professor of Psychology
# 431    Liya Zalaltdinova                       Visiting Lecturer in Russian
# 432      Sofia E. Zepeda             Assistant Professor at Williams-Mystic
# 433   David J. Zimmerman  Professor of Economics and Orrin Sage Professo...
# 434       Charles U. Zug  Visiting Assistant Professor of Leadership Stu...
#
# ...
